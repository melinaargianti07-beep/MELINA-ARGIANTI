# %% [markdown]
# <a href="https://colab.research.google.com/github/melinaargianti07-beep/MELINA-ARGIANTI/blob/main/Modul_5_melina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            while True:
                try:
                    val = float(input(f"Elemen [{i+1},{j+1}]: "))
                    row.append(val)
                    break
                except ValueError:
                    print("Input harus angka!")
        matriks.append(row)
    return matriks


def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{elemen:.2f}" for elemen in row))


def penjumlahan_matriks(A, B):
    baris = len(A)
    kolom = len(A[0])
    C = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C


def perkalian_matriks(A, B):
    m = len(A)
    p = len(A[0])
    n = len(B[0])
    C = []
    for i in range(m):
        row = []
        for j in range(n):
            total = 0
            for k in range(p):
                total += A[i][k] * B[k][j]
            row.append(total)
        C.append(row)
    return C


def transpose_matriks(A):
    return [[A[j][i] for j in range(len(A))] for i in range(len(A[0]))]


def main():
    print("\n=== KASUS 1: Matriks 2x2 ===")
    A = input_matriks(2, 2, "A")
    B = input_matriks(2, 2, "B")

    while True:
        print("\n===== MENU =====")
        print("1. Penjumlahan")
        print("2. Perkalian")
        print("3. Transpose")
        print("4. Keluar")
        pilih = input("Pilih operasi: ")

        if pilih == "1":
            print("\nHasil Penjumlahan:")
            print_matriks(penjumlahan_matriks(A, B))

        elif pilih == "2":
            print("\nHasil Perkalian:")
            print_matriks(perkalian_matriks(A, B))

        elif pilih == "3":
            print("\nTranspose Matriks A:")
            print_matriks(transpose_matriks(A))
            print("\nTranspose Matriks B:")
            print_matriks(transpose_matriks(B))

        elif pilih == "4":
            break

        else:
            print("Pilihan tidak tersedia!")

if __name__ == "__main__":
    main()
# Out:
# === KASUS 1: Matriks 2x2 ===
#
# Masukkan elemen matriks A (2x2):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 4
#
# Masukkan elemen matriks B (2x2):
# Elemen [1,1]: 5
# Elemen [1,2]: 6
# Elemen [2,1]: 7
# Elemen [2,2]: 8
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 1
#
# Hasil Penjumlahan:
# 6.00	8.00
# 10.00	12.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 2
#
# Hasil Perkalian:
# 19.00	22.00
# 43.00	50.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 3
#
# Transpose Matriks A:
# 1.00	3.00
# 2.00	4.00
#
# Transpose Matriks B:
# 5.00	7.00
# 6.00	8.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 4

# %%
#kasus 2
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            while True:
                try:
                    val = float(input(f"Elemen [{i+1},{j+1}]: "))
                    row.append(val)
                    break
                except ValueError:
                    print("Input harus angka!")
        matriks.append(row)
    return matriks


def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{elemen:.2f}" for elemen in row))


def penjumlahan_matriks(A, B):
    baris = len(A)
    kolom = len(A[0])
    C = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C


def perkalian_matriks(A, B):
    m = len(A)
    p = len(A[0])
    n = len(B[0])
    C = []
    for i in range(m):
        row = []
        for j in range(n):
            total = 0
            for k in range(p):
                total += A[i][k] * B[k][j]
            row.append(total)
        C.append(row)
    return C


def transpose_matriks(A):
    return [[A[j][i] for j in range(len(A))] for i in range(len(A[0]))]


def main():
    print("\n=== KASUS 2: Matriks A(2x3) dan B(3x2) ===")
    A = input_matriks(2, 3, "A")
    B = input_matriks(3, 2, "B")

    while True:
        print("\n===== MENU =====")
        print("1. Penjumlahan")
        print("2. Perkalian")
        print("3. Transpose")
        print("4. Keluar")
        pilih = input("Pilih operasi: ")

        if pilih == "1":
            print("\n❌ Penjumlahan tidak dapat dilakukan (ukuran berbeda)")

        elif pilih == "2":
            print("\nHasil Perkalian:")
            print_matriks(perkalian_matriks(A, B))

        elif pilih == "3":
            print("\nTranspose Matriks A:")
            print_matriks(transpose_matriks(A))
            print("\nTranspose Matriks B:")
            print_matriks(transpose_matriks(B))

        elif pilih == "4":
            break

        else:
            print("Pilihan tidak tersedia!")


if __name__ == "__main__":
    main()
# Out:
# === KASUS 2: Matriks A(2x3) dan B(3x2) ===
#
# Masukkan elemen matriks A (2x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 4
# Elemen [2,2]: 5
# Elemen [2,3]: 6
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 8
# Elemen [2,1]: 9
# Elemen [2,2]: 10
# Elemen [3,1]: 11
# Elemen [3,2]: 12
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 1
#
# ❌ Penjumlahan tidak dapat dilakukan (ukuran berbeda)
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 2
#
# Hasil Perkalian:
# 58.00	64.00
# 139.00	154.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 3
#
# Transpose Matriks A:
# 1.00	4.00
# 2.00	5.00
# 3.00	6.00
#
# Transpose Matriks B:
# 7.00	9.00	11.00
# 8.00	10.00	12.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 4

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            while True:
                try:
                    val = float(input(f"Elemen [{i+1},{j+1}]: "))
                    row.append(val)
                    break
                except ValueError:
                    print("Input harus angka!")
        matriks.append(row)
    return matriks


def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{elemen:.2f}" for elemen in row))


def penjumlahan_matriks(A, B):
    baris = len(A)
    kolom = len(A[0])
    C = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C


def perkalian_matriks(A, B):
    m = len(A)
    p = len(A[0])
    n = len(B[0])
    C = []
    for i in range(m):
        row = []
        for j in range(n):
            total = 0
            for k in range(p):
                total += A[i][k] * B[k][j]
            row.append(total)
        C.append(row)
    return C


def transpose_matriks(A):
    return [[A[j][i] for j in range(len(A))] for i in range(len(A[0]))]


def main():
    print("\n=== KASUS 3: Matriks 3x3 ===")
    A = input_matriks(3, 3, "A")
    B = input_matriks(3, 3, "B")

    while True:
        print("\n===== MENU =====")
        print("1. Penjumlahan")
        print("2. Perkalian")
        print("3. Transpose")
        print("4. Keluar")
        pilih = input("Pilih operasi: ")

        if pilih == "1":
            print("\nHasil Penjumlahan:")
            print_matriks(penjumlahan_matriks(A, B))

        elif pilih == "2":
            print("\nHasil Perkalian:")
            print_matriks(perkalian_matriks(A, B))

        elif pilih == "3":
            print("\nTranspose Matriks A:")
            print_matriks(transpose_matriks(A))
            print("\nTranspose Matriks B:")
            print_matriks(transpose_matriks(B))

        elif pilih == "4":
            break

        else:
            print("Pilihan tidak tersedia!")


if __name__ == "__main__":
    main()
# Out:
# === KASUS 3: Matriks 3x3 ===
#
# Masukkan elemen matriks A (3x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 4
# Elemen [2,2]: 5
# Elemen [2,3]: 6
# Elemen [3,1]: 7
# Elemen [3,2]: 8
# Elemen [3,3]: 9
#
# Masukkan elemen matriks B (3x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 4
# Elemen [2,2]: 5
# Elemen [2,3]: 6
# Elemen [3,1]: 7
# Elemen [3,2]: 8
# Elemen [3,3]: 9
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 1
#
# Hasil Penjumlahan:
# 2.00	4.00	6.00
# 8.00	10.00	12.00
# 14.00	16.00	18.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 2
#
# Hasil Perkalian:
# 30.00	36.00	42.00
# 66.00	81.00	96.00
# 102.00	126.00	150.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 3
#
# Transpose Matriks A:
# 1.00	4.00	7.00
# 2.00	5.00	8.00
# 3.00	6.00	9.00
#
# Transpose Matriks B:
# 1.00	4.00	7.00
# 2.00	5.00	8.00
# 3.00	6.00	9.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 4

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            while True:
                try:
                    val = float(input(f"Elemen [{i+1},{j+1}]: "))
                    row.append(val)
                    break
                except ValueError:
                    print("Input harus angka!")
        matriks.append(row)
    return matriks


def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{elemen:.2f}" for elemen in row))


def penjumlahan_matriks(A, B):
    baris = len(A)
    kolom = len(A[0])
    C = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C


def perkalian_matriks(A, B):
    print("\n❌ Perkalian tidak bisa dilakukan (kolom A ≠ baris B)")
    return None


def transpose_matriks(A):
    return [[A[j][i] for j in range(len(A))] for i in range(len(A[0]))]


def main():
    print("\n=== KASUS 4: Matriks A(3x2) dan B(3x2) ===")
    A = input_matriks(3, 2, "A")
    B = input_matriks(3, 2, "B")

    while True:
        print("\n===== MENU =====")
        print("1. Penjumlahan")
        print("2. Perkalian")
        print("3. Transpose")
        print("4. Keluar")
        pilih = input("Pilih operasi: ")

        if pilih == "1":
            print("\nHasil Penjumlahan:")
            print_matriks(penjumlahan_matriks(A, B))

        elif pilih == "2":
            perkalian_matriks(A, B)

        elif pilih == "3":
            print("\nTranspose Matriks A:")
            print_matriks(transpose_matriks(A))
            print("\nTranspose Matriks B:")
            print_matriks(transpose_matriks(B))

        elif pilih == "4":
            break

        else:
            print("Pilihan tidak tersedia!")


if __name__ == "__main__":
    main()
# Out:
# === KASUS 4: Matriks A(3x2) dan B(3x2) ===
#
# Masukkan elemen matriks A (3x2):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 4
# Elemen [3,1]: 5
# Elemen [3,2]: 6
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 8
# Elemen [2,1]: 9
# Elemen [2,2]: 10
# Elemen [3,1]: 11
# Elemen [3,2]: 12
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 1
#
# Hasil Penjumlahan:
# 8.00	10.00
# 12.00	14.00
# 16.00	18.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 2
#
# ❌ Perkalian tidak bisa dilakukan (kolom A ≠ baris B)
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 3
#
# Transpose Matriks A:
# 1.00	3.00	5.00
# 2.00	4.00	6.00
#
# Transpose Matriks B:
# 7.00	9.00	11.00
# 8.00	10.00	12.00
#
# ===== MENU =====
# 1. Penjumlahan
# 2. Perkalian
# 3. Transpose
# 4. Keluar
# Pilih operasi: 4
